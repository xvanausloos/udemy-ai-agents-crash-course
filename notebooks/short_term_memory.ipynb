# %% [markdown]
# # Short-Term Memory

# %%
import dotenv
from agents import Agent, Runner, SQLiteSession, trace

dotenv.load_dotenv()
# Out:
# True

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
)

# %% [markdown]
# ## No Memory

# %%
result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")
print(result.final_output)
# Out:
# Bananas are healthier than lollipops.
#
# 1) Bananas: 7/10 - Rich in potassium, fiber, and vitamins; natural sugars.
# 2) Lollipop: 1/10 - Mostly added sugar; few to no nutrients.

# %%
result = await Runner.run(nutrition_agent, "Add apples to the comparison")
print(result.final_output)
# Out:
# Sure— which foods should I compare (including apples)? Please list the items you want included, and I’ll rank them 1–10 with brief notes.

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?",
    session=session
)
print(result.final_output)
# Out:
# Bananas are healthier.
#
# 1) Bananas: 8/10 - Good fiber, potassium, vitamins; natural sugars but overall nutrient-dense.
# 2) Lollipop: 2/10 - Mostly refined sugar; little to no nutrients.

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison",
        session=session
    )

print(result.final_output)
# Out:
# 1) Bananas: 8/10 - Good fiber and potassium; nutrient-dense with natural sugars.
# 2) Apples: 7/10 - Fiber and vitamin C; healthy polyphenols, fewer calories than bananas.
# 3) Lollipop: 2/10 - Mostly refined sugar; few nutrients.
